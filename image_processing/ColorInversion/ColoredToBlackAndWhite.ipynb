# %%
from PIL import Image
import time
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook 
from matplotlib import style
style.use("ggplot")
from functools import reduce

# %% [markdown]
# ## Before

# %%
i=Image.open('images/numbers/0.1.png')
iar=np.array(i)

i2=Image.open('images/numbers/y0.4.png')
iar2=np.array(i2)

i3=Image.open('images/numbers/y0.5.png')
iar3=np.array(i3)

i4=Image.open('images/sentdex.png')
iar4=np.array(i4)

# %%
fig=plt.figure()
ax1=plt.subplot2grid( (8,6), (0,0), rowspan=4, colspan=3 )
ax2=plt.subplot2grid( (8,6), (4,0), rowspan=4, colspan=3 )
ax3=plt.subplot2grid( (8,6), (0,3), rowspan=4, colspan=3 )
ax4=plt.subplot2grid( (8,6), (4,3), rowspan=4, colspan=3 )

ax1.imshow(iar)
ax2.imshow(iar2)
ax3.imshow(iar3)
ax4.imshow(iar4)

plt.show()
plt.savefig('before.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Applying the function

# %%
def threshold(imageArray): # function to convert an image to black and white
    balanceArray=[]
    newAr=imageArray
    
    for eachRow in imageArray: 
        for eachPix in eachRow:
            avgNum=reduce(lambda x,y:x+y,eachPix[:3])/len(eachPix[:3])
            # instead
            # from statistics import mean
            # avgNum=mean(eachPix[:3]) could also be done
            balanceArray.append(avgNum)
    balance=reduce(lambda x,y:x+y,balanceArray)/len(balanceArray)    

    for eachRow in newAr:
        for eachPix in eachRow:
            if reduce(lambda x,y:x+y,eachPix[:3])/len(eachPix[:3])>balance:
                eachPix[0]=255
                eachPix[1]=255
                eachPix[2]=255
                eachPix[3]=255
            else:
                eachPix[0]=0
                eachPix[1]=0
                eachPix[2]=0
                eachPix[3]=255
    return newAr

# %% [markdown]
# ## After

# %%
threshold(iar3)
threshold(iar2)
threshold(iar4)
# Out:
# /home/saurabh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: overflow encountered in ubyte_scalars
#   import sys
# /home/saurabh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: overflow encountered in ubyte_scalars
#   app.launch_new_instance()
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [  0,   0,   0, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [  0,   0,   0, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]]], dtype=uint8)

# %%
fig=plt.figure()
ax1=plt.subplot2grid( (8,6), (0,0), rowspan=4, colspan=3 )
ax2=plt.subplot2grid( (8,6), (4,0), rowspan=4, colspan=3 )
ax3=plt.subplot2grid( (8,6), (0,3), rowspan=4, colspan=3 )
ax4=plt.subplot2grid( (8,6), (4,3), rowspan=4, colspan=3 )

ax1.imshow(iar)
ax2.imshow(iar2)
ax3.imshow(iar3)
ax4.imshow(iar4)

plt.show()
plt.savefig('after.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
