# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
from sklearn import datasets,linear_model, metrics

# %%
boston = datasets.load_boston()
X = boston.data 
y = boston.target
# X=pd.DataFrame(X)
# print(X)
# y=pd.DataFrame(y)
# print(y)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,random_state=1) 
# print(X_train.shape)
# print(y_train.shape)
# print(X_test.shape)
# print(y_test.shape)

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
print('Coefficients: \n', reg.coef_)
# Out:
# Coefficients:
#  [-8.80740828e-02  6.72507352e-02  5.10280463e-02  2.18879172e+00
#  -1.72283734e+01  3.62985243e+00  2.13933641e-03 -1.36531300e+00
#   2.88788067e-01 -1.22618657e-02 -8.36014969e-01  9.53058061e-03
#  -5.05036163e-01]

# %%
print('Variance score: ',reg.score(X_test, y_test))
# Out:
# Variance score:  0.7208987846108872

# %%
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train, 
            color = "green", s = 10, label = 'Train data') 
  
 
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test, 
            color = "blue", s = 10, label = 'Test data') 
  
 
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2) 

plt.legend(loc = 'upper right')  
plt.title("Residual errors") 
plt.show()

# %%
plt.scatter(reg.predict(X_train),y_train,label="Train data")
plt.scatter(reg.predict(X_test),y_test, color = "g",label="Test data") 
plt.legend(loc = 'lower right')  
plt.title("Test Vs Train") 
plt.show()
